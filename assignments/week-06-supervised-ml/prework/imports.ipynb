# %%
# !pip install pandas-profiling
# Out:
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.5.0-py2.py3-none-any.whl (325 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.0/325.0 kB 2.8 MB/s eta 0:00:000:00:01m eta 0:00:01
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /home/sveta/.local/lib/python3.8/site-packages (from pandas-profiling) (6.0)
# Requirement already satisfied: pandas!=1.4.0,<1.6,>1.1 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from pandas-profiling) (1.5.1)
# Collecting multimethod<1.10,>=1.4
#   Downloading multimethod-1.9-py3-none-any.whl (10 kB)
# Collecting visions[type_image_path]==0.7.5
#   Downloading visions-0.7.5-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: scipy<1.10,>=1.4.1 in /home/sveta/.local/lib/python3.8/site-packages (from pandas-profiling) (1.5.4)
# Collecting statsmodels<0.14,>=0.13.2
#   Downloading statsmodels-0.13.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 5.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: tqdm<4.65,>=4.48.2 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from pandas-profiling) (4.64.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /home/sveta/.local/lib/python3.8/site-packages (from pandas-profiling) (3.1.2)
# Collecting pydantic<1.11,>=1.8.1
#   Downloading pydantic-1.10.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 5.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from pandas-profiling) (0.12.1)
# Collecting phik<0.13,>=0.11.1
#   Downloading phik-0.12.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (696 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 696.1/696.1 kB 3.8 MB/s eta 0:00:000:00:01m eta 0:00:01
# Requirement already satisfied: numpy<1.24,>=1.16.0 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from pandas-profiling) (1.23.4)
# Requirement already satisfied: matplotlib<3.7,>=3.2 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from pandas-profiling) (3.6.2)
# Collecting typeguard<2.14,>=2.13.2
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Collecting htmlmin==0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests<2.29,>=2.24.0 in /home/sveta/.local/lib/python3.8/site-packages (from pandas-profiling) (2.27.1)
# Requirement already satisfied: attrs>=19.3.0 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from visions[type_image_path]==0.7.5->pandas-profiling) (22.1.0)
# Collecting tangled-up-in-unicode>=0.0.4
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 3.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: networkx>=2.4 in /home/sveta/.local/lib/python3.8/site-packages (from visions[type_image_path]==0.7.5->pandas-profiling) (2.8)
# Collecting imagehash
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 4.1 MB/s eta 0:00:009.1 MB/s eta 0:00:01
# Requirement already satisfied: Pillow in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from visions[type_image_path]==0.7.5->pandas-profiling) (9.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sveta/.local/lib/python3.8/site-packages (from jinja2<3.2,>=2.11.1->pandas-profiling) (2.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from matplotlib<3.7,>=3.2->pandas-profiling) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from matplotlib<3.7,>=3.2->pandas-profiling) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from matplotlib<3.7,>=3.2->pandas-profiling) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from matplotlib<3.7,>=3.2->pandas-profiling) (4.37.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from matplotlib<3.7,>=3.2->pandas-profiling) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from matplotlib<3.7,>=3.2->pandas-profiling) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from matplotlib<3.7,>=3.2->pandas-profiling) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from pandas!=1.4.0,<1.6,>1.1->pandas-profiling) (2022.5)
# Requirement already satisfied: joblib>=0.14.1 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from phik<0.13,>=0.11.1->pandas-profiling) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/sveta/.local/lib/python3.8/site-packages (from pydantic<1.11,>=1.8.1->pandas-profiling) (4.1.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/sveta/.local/lib/python3.8/site-packages (from requests<2.29,>=2.24.0->pandas-profiling) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from requests<2.29,>=2.24.0->pandas-profiling) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from requests<2.29,>=2.24.0->pandas-profiling) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from requests<2.29,>=2.24.0->pandas-profiling) (3.4)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 kB 2.8 MB/s eta 0:00:009.0 MB/s eta 0:00:01
# Requirement already satisfied: six in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from patsy>=0.5.2->statsmodels<0.14,>=0.13.2->pandas-profiling) (1.16.0)
# Requirement already satisfied: PyWavelets in /home/sveta/.local/lib/python3.8/site-packages (from imagehash->visions[type_image_path]==0.7.5->pandas-profiling) (1.3.0)
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27082 sha256=a260a0382fdf5117e4c03756bbb368d047db2b17f1e03525506a466479ae9191
#   Stored in directory: /home/sveta/.cache/pip/wheels/28/f3/26/826f91b0c848ff98f1725cd43014a6f3a2d961114157d790db
# Successfully built htmlmin
# Installing collected packages: htmlmin, typeguard, tangled-up-in-unicode, pydantic, patsy, multimethod, imagehash, visions, statsmodels, phik, pandas-profiling
# Successfully installed htmlmin-0.1.12 imagehash-4.3.1 multimethod-1.9 pandas-profiling-3.5.0 patsy-0.5.3 phik-0.12.2 pydantic-1.10.2 statsmodels-0.13.5 tangled-up-in-unicode-0.2.0 typeguard-2.13.3 visions-0.7.5
#
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install -r requirements.txt
# Out:
# Collecting ipython==8.4.0
#   Downloading ipython-8.4.0-py3-none-any.whl (750 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.8/750.8 kB 941.7 kB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting matplotlib==3.5.2
#   Downloading matplotlib-3.5.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 3.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting numpy==1.23.1
#   Downloading numpy-1.23.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 2.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting pandas==1.4.3
#   Downloading pandas-1.4.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 5.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting plotly==5.9.0
#   Downloading plotly-5.9.0-py2.py3-none-any.whl (15.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.2/15.2 MB 4.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting scikit_learn==1.1.1
#   Downloading scikit_learn-1.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.2/31.2 MB 3.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting seaborn==0.11.2
#   Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.8/292.8 kB 3.6 MB/s eta 0:00:000:00:010:00:01
# Collecting shap
#   Downloading shap-0.41.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (575 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 575.9/575.9 kB 4.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting streamlit==1.11.1
#   Downloading streamlit-1.11.1-py2.py3-none-any.whl (9.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 5.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: pygments>=2.4.0 in /home/sveta/.local/lib/python3.8/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (2.13.0)
# Requirement already satisfied: backcall in /home/sveta/.local/lib/python3.8/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /home/sveta/.local/lib/python3.8/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /home/sveta/.local/lib/python3.8/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (0.1.6)
# Requirement already satisfied: pickleshare in /home/sveta/.local/lib/python3.8/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (63.4.1)
# Requirement already satisfied: decorator in /home/sveta/.local/lib/python3.8/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (5.1.1)
# Requirement already satisfied: traitlets>=5 in /home/sveta/.local/lib/python3.8/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (5.5.0)
# Requirement already satisfied: stack-data in /home/sveta/.local/lib/python3.8/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/sveta/.local/lib/python3.8/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (3.0.31)
# Requirement already satisfied: cycler>=0.10 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from matplotlib==3.5.2->-r requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from matplotlib==3.5.2->-r requirements.txt (line 2)) (4.37.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from matplotlib==3.5.2->-r requirements.txt (line 2)) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from matplotlib==3.5.2->-r requirements.txt (line 2)) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from matplotlib==3.5.2->-r requirements.txt (line 2)) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from matplotlib==3.5.2->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from matplotlib==3.5.2->-r requirements.txt (line 2)) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from pandas==1.4.3->-r requirements.txt (line 4)) (2022.5)
# Requirement already satisfied: tenacity>=6.2.0 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from plotly==5.9.0->-r requirements.txt (line 5)) (8.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from scikit_learn==1.1.1->-r requirements.txt (line 6)) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /home/sveta/.local/lib/python3.8/site-packages (from scikit_learn==1.1.1->-r requirements.txt (line 6)) (1.5.4)
# Requirement already satisfied: joblib>=1.0.0 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from scikit_learn==1.1.1->-r requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: protobuf<4,>=3.12 in /home/sveta/.local/lib/python3.8/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (3.19.4)
# Collecting gitpython!=3.1.19
#   Using cached GitPython-3.1.29-py3-none-any.whl (182 kB)
# Collecting click>=7.0
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Collecting altair>=3.2.0
#   Downloading altair-4.2.0-py3-none-any.whl (812 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 812.8/812.8 kB 4.0 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: requests>=2.4 in /home/sveta/.local/lib/python3.8/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (2.27.1)
# Requirement already satisfied: cachetools>=4.0 in /home/sveta/.local/lib/python3.8/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (5.0.0)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /home/sveta/.local/lib/python3.8/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (4.1.1)
# Collecting pyarrow>=4.0
#   Downloading pyarrow-10.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.0/36.0 MB 3.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.8.0-py2.py3-none-any.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 4.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 4.2 MB/s eta 0:00:00m eta 0:00:01
# Requirement already satisfied: attrs>=16.0.0 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (22.1.0)
# Collecting blinker>=1.0.0
#   Using cached blinker-1.5-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: importlib-metadata>=1.4 in /home/sveta/.local/lib/python3.8/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (4.11.1)
# Collecting semver
#   Downloading semver-2.13.0-py2.py3-none-any.whl (12 kB)
# Collecting rich>=10.11.0
#   Using cached rich-12.6.0-py3-none-any.whl (237 kB)
# Collecting tzlocal>=1.1
#   Downloading tzlocal-4.2-py3-none-any.whl (19 kB)
# Collecting validators>=0.2
#   Downloading validators-0.20.0.tar.gz (30 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tornado>=5.0 in /home/sveta/.local/lib/python3.8/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (6.2)
# Collecting watchdog
#   Downloading watchdog-2.1.9-py3-none-manylinux2014_x86_64.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 3.6 MB/s eta 0:00:00
# Collecting numba
#   Downloading numba-0.56.4-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 1.8 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: tqdm>4.25.0 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from shap->-r requirements.txt (line 8)) (4.64.1)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Collecting cloudpickle
#   Downloading cloudpickle-2.2.0-py3-none-any.whl (25 kB)
# Collecting toolz
#   Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema>=3.0 in /home/sveta/.local/lib/python3.8/site-packages (from altair>=3.2.0->streamlit==1.11.1->-r requirements.txt (line 9)) (4.16.0)
# Requirement already satisfied: jinja2 in /home/sveta/.local/lib/python3.8/site-packages (from altair>=3.2.0->streamlit==1.11.1->-r requirements.txt (line 9)) (3.1.2)
# Requirement already satisfied: entrypoints in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from altair>=3.2.0->streamlit==1.11.1->-r requirements.txt (line 9)) (0.4)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.10-py3-none-any.whl (62 kB)
# Requirement already satisfied: zipp>=0.5 in /home/sveta/.local/lib/python3.8/site-packages (from importlib-metadata>=1.4->streamlit==1.11.1->-r requirements.txt (line 9)) (3.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/sveta/.local/lib/python3.8/site-packages (from jedi>=0.16->ipython==8.4.0->-r requirements.txt (line 1)) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/sveta/.local/lib/python3.8/site-packages (from pexpect>4.3->ipython==8.4.0->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: wcwidth in /home/sveta/.local/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython==8.4.0->-r requirements.txt (line 1)) (0.2.5)
# Requirement already satisfied: six>=1.5 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib==3.5.2->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from requests>=2.4->streamlit==1.11.1->-r requirements.txt (line 9)) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from requests>=2.4->streamlit==1.11.1->-r requirements.txt (line 9)) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from requests>=2.4->streamlit==1.11.1->-r requirements.txt (line 9)) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/sveta/.local/lib/python3.8/site-packages (from requests>=2.4->streamlit==1.11.1->-r requirements.txt (line 9)) (2.0.12)
# Collecting commonmark<0.10.0,>=0.9.0
#   Using cached commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
# Collecting pytz-deprecation-shim
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Collecting backports.zoneinfo
#   Downloading backports.zoneinfo-0.2.1-cp38-cp38-manylinux1_x86_64.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 257.6 kB/s eta 0:00:0031m6.1 MB/s eta 0:00:01
# Collecting llvmlite<0.40,>=0.39.0dev0
#   Downloading llvmlite-0.39.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.6/34.6 MB 2.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: executing in /home/sveta/.local/lib/python3.8/site-packages (from stack-data->ipython==8.4.0->-r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: asttokens in /home/sveta/.local/lib/python3.8/site-packages (from stack-data->ipython==8.4.0->-r requirements.txt (line 1)) (2.0.8)
# Requirement already satisfied: pure-eval in /home/sveta/.local/lib/python3.8/site-packages (from stack-data->ipython==8.4.0->-r requirements.txt (line 1)) (0.2.2)
# Collecting smmap<6,>=3.0.1
#   Using cached smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sveta/.local/lib/python3.8/site-packages (from jinja2->altair>=3.2.0->streamlit==1.11.1->-r requirements.txt (line 9)) (2.1.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/sveta/.local/lib/python3.8/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==1.11.1->-r requirements.txt (line 9)) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /home/sveta/.local/lib/python3.8/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==1.11.1->-r requirements.txt (line 9)) (5.10.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /home/sveta/.local/lib/python3.8/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==1.11.1->-r requirements.txt (line 9)) (1.3.10)
# Collecting tzdata
#   Downloading tzdata-2022.7-py2.py3-none-any.whl (340 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 340.1/340.1 kB 3.0 MB/s eta 0:00:00 MB/s eta 0:00:01
# Building wheels for collected packages: validators
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19579 sha256=70efaed922402020a018722ee1cdca01c526a5662ed7833208c8cac1d487cf9f
#   Stored in directory: /home/sveta/.cache/pip/wheels/cb/aa/fe/3316d4394e9ad09ea76561bd5be33f6d01828ff125ab2a3395
# Successfully built validators
# Installing collected packages: commonmark, watchdog, validators, tzdata, toolz, toml, smmap, slicer, semver, rich, pympler, plotly, numpy, llvmlite, cloudpickle, click, blinker, backports.zoneinfo, pytz-deprecation-shim, pydeck, pyarrow, pandas, numba, matplotlib, gitdb, tzlocal, seaborn, scikit_learn, ipython, gitpython, altair, streamlit, shap
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.11.0
#     Uninstalling plotly-5.11.0:
#       Successfully uninstalled plotly-5.11.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.4
#     Uninstalling numpy-1.23.4:
#       Successfully uninstalled numpy-1.23.4
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.1
#     Uninstalling pandas-1.5.1:
#       Successfully uninstalled pandas-1.5.1
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.6.2
#     Uninstalling matplotlib-3.6.2:
#       Successfully uninstalled matplotlib-3.6.2
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.12.1
#     Uninstalling seaborn-0.12.1:
#       Successfully uninstalled seaborn-0.12.1
#   Attempting uninstall: scikit_learn
#     Found existing installation: scikit-learn 1.1.3
#     Uninstalling scikit-learn-1.1.3:
#       Successfully uninstalled scikit-learn-1.1.3
#   Attempting uninstall: ipython
#     Found existing installation: ipython 8.5.0
#     Uninstalling ipython-8.5.0:
#       Successfully uninstalled ipython-8.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# openvino-dev 2021.4.2 requires openvino==2021.4.2, which is not installed.
# hyperopt 0.1.2 requires future, which is not installed.
# torchvision 0.12.0 requires torch==1.11.0, but you have torch 1.13.0 which is incompatible.
# openvino-dev 2021.4.2 requires numpy<1.20,>=1.16.6, but you have numpy 1.23.1 which is incompatible.
# openvino-dev 2021.4.2 requires pandas~=1.1.5, but you have pandas 1.4.3 which is incompatible.
# Successfully installed altair-4.2.0 backports.zoneinfo-0.2.1 blinker-1.5 click-8.1.3 cloudpickle-2.2.0 commonmark-0.9.1 gitdb-4.0.10 gitpython-3.1.29 ipython-8.5.0 llvmlite-0.39.1 matplotlib-3.5.2 numba-0.56.4 numpy-1.23.1 pandas-1.4.3 plotly-5.9.0 pyarrow-10.0.1 pydeck-0.8.0 pympler-1.0.1 pytz-deprecation-shim-0.1.0.post0 rich-12.6.0 scikit_learn-1.1.1 seaborn-0.11.2 semver-2.13.0 shap-0.41.0 slicer-0.0.7 smmap-5.0.0 streamlit-1.11.1 toml-0.10.2 toolz-0.12.0 tzdata-2022.7 tzlocal-4.2 validators-0.20.0 watchdog-2.1.9
#
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install tpot
# Out:
# Collecting tpot
#   Downloading TPOT-0.11.7-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 2.1 MB/s eta 0:00:004.6 MB/s eta 0:00:01
# Requirement already satisfied: tqdm>=4.36.1 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from tpot) (4.64.1)
# Requirement already satisfied: scikit-learn>=0.22.0 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from tpot) (1.1.1)
# Requirement already satisfied: joblib>=0.13.2 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from tpot) (1.2.0)
# Collecting deap>=1.2
#   Downloading deap-1.3.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 1.9 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting stopit>=1.1.1
#   Downloading stopit-1.1.2.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.16.3 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from tpot) (1.23.1)
# Requirement already satisfied: pandas>=0.24.2 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from tpot) (1.4.3)
# Requirement already satisfied: scipy>=1.3.1 in /home/sveta/.local/lib/python3.8/site-packages (from tpot) (1.5.4)
# Collecting xgboost>=1.1.0
#   Downloading xgboost-1.7.1-py3-none-manylinux2014_x86_64.whl (193.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 MB 2.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: update-checker>=0.16 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from tpot) (0.18.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from pandas>=0.24.2->tpot) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from pandas>=0.24.2->tpot) (2022.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from scikit-learn>=0.22.0->tpot) (3.1.0)
# Requirement already satisfied: requests>=2.3.0 in /home/sveta/.local/lib/python3.8/site-packages (from update-checker>=0.16->tpot) (2.27.1)
# Requirement already satisfied: six>=1.5 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas>=0.24.2->tpot) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/sveta/.local/lib/python3.8/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /home/sveta/anaconda3/envs/mle-course/lib/python3.8/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.4)
# Building wheels for collected packages: stopit
#   Building wheel for stopit (setup.py) ... done
#   Created wheel for stopit: filename=stopit-1.1.2-py3-none-any.whl size=11939 sha256=0d14e17f08aa86aa35c939d244e75d9fb05425149e8abdc9e6d0daef9c801f2b
#   Stored in directory: /home/sveta/.cache/pip/wheels/0f/f8/a0/36061cd4f93361be3432191e2504e12a1f5fab5d1ab6a0063b
# Successfully built stopit
# Installing collected packages: stopit, deap, xgboost, tpot
# Successfully installed deap-1.3.3 stopit-1.1.2 tpot-0.11.7 xgboost-1.7.1
#
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport
import matplotlib.pyplot as plt
import plotly 
import sklearn 
import shap
import tpot
#import streamlit as st

# %%
import streamlit as st

# https://discuss.streamlit.io/t/running-streamlit-in-a-jupyter-cell/584
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [12], line 1
# ----> 1 import streamlit as st
#
# File ~/anaconda3/envs/mle-course/lib/python3.8/site-packages/streamlit/__init__.py:70
#      68 from streamlit import source_util as _source_util
#      69 from streamlit import string_util as _string_util
# ---> 70 from streamlit.delta_generator import DeltaGenerator as _DeltaGenerator
#      71 from streamlit.scriptrunner import (
#      72     add_script_run_ctx as _add_script_run_ctx,
#      73     get_script_run_ctx as _get_script_run_ctx,
#    (...)
#      76     RerunData as _RerunData,
#      77 )
#      78 from streamlit.errors import StreamlitAPIException
#
# File ~/anaconda3/envs/mle-course/lib/python3.8/site-packages/streamlit/delta_generator.py:89
#      85 from streamlit.state import NoValue
#      87 # DataFrame elements come in two flavors: "Legacy" and "Arrow".
#      88 # We select between them with the DataFrameElementSelectorMixin.
# ---> 89 from streamlit.elements.arrow import ArrowMixin
#      90 from streamlit.elements.arrow_altair import ArrowAltairMixin
#      91 from streamlit.elements.arrow_vega_lite import ArrowVegaLiteMixin
#
# File ~/anaconda3/envs/mle-course/lib/python3.8/site-packages/streamlit/elements/arrow.py:21
#      19 from numpy import ndarray
#      20 from pandas import DataFrame
# ---> 21 from pandas.io.formats.style import Styler
#      22 import pyarrow as pa
#      24 from streamlit import type_util
#
# File ~/anaconda3/envs/mle-course/lib/python3.8/site-packages/pandas/io/formats/style.py:105
#      95 props = """
#      96         props : str, default None
#      97             CSS properties to use for highlighting. If ``props`` is given, ``color``
#      98             is not used.
#      99 """
#     101 #
#     102 ###
# --> 105 class Styler(StylerRenderer):
#     106     r"""
#     107     Helps style a DataFrame or Series according to the data with HTML and CSS.
#     108
#    (...)
#     217     *{"row": "MY_ROW_CLASS", "col_trim": "", "row_trim": ""}*.
#     218     """
#     220     def __init__(
#     221         self,
#     222         data: DataFrame | Series,
#    (...)
#     234         formatter: ExtFormatter | None = None,
#     235     ):
#
# File ~/anaconda3/envs/mle-course/lib/python3.8/site-packages/pandas/io/formats/style.py:447, in Styler()
#     438         self.tooltips.class_name = css_class
#     440     return self
#     442 @doc(
#     443     NDFrame.to_excel,
#     444     klass="Styler",
#     445     storage_options=_shared_docs["storage_options"],
#     446 )
# --> 447 def to_excel(
#     448     self,
#     449     excel_writer,
#     450     sheet_name: str = "Sheet1",
#     451     na_rep: str = "",
#     452     float_format: str | None = None,
#     453     columns: Sequence[Hashable] | None = None,
#     454     header: Sequence[Hashable] | bool = True,
#     455     index: bool = True,
#     456     index_label: IndexLabel | None = None,
#     457     startrow: int = 0,
#     458     startcol: int = 0,
#     459     engine: str | None = None,
#     460     merge_cells: bool = True,
#     461     encoding: str | None = None,
#     462     inf_rep: str = "inf",
#     463     verbose: bool = True,
#     464     freeze_panes: tuple[int, int] | None = None,
#     465 ) -> None:
#     467     from pandas.io.formats.excel import ExcelFormatter
#     469     formatter = ExcelFormatter(
#     470         self,
#     471         na_rep=na_rep,
#    (...)
#     478         inf_rep=inf_rep,
#     479     )
#
# File ~/anaconda3/envs/mle-course/lib/python3.8/site-packages/pandas/util/_decorators.py:411, in decorator(decorated)
#     409 class Substitution:
#     410     """
# --> 411     A decorator to take a function's docstring and perform string
#     412     substitution on it.
#     413
#     414     This decorator should be robust even if func.__doc__ is None
#     415     (for example, if -OO was passed to the interpreter)
#     416
#     417     Usage: construct a docstring.Substitution with a sequence or
#     418     dictionary suitable for performing substitution; then
#     419     decorate a suitable function with the constructed object. e.g.
#     420
#     421     sub_author_name = Substitution(author='Jason')
#     422
#     423     @sub_author_name
#     424     def some_function(x):
#     425         "%(author)s wrote this function"
#     426
#     427     # note that some_function.__doc__ is now "Jason wrote this function"
#     428
#     429     One can also use positional arguments.
#     430
#     431     sub_first_last_names = Substitution('Edgar Allen', 'Poe')
#     432
#     433     @sub_first_last_names
#     434     def some_function(x):
#     435         "%s %s wrote the Raven"
#     436     """
#     438     def __init__(self, *args, **kwargs):
#     439         if args and kwargs:
#
# File ~/anaconda3/envs/mle-course/lib/python3.8/site-packages/pandas/util/_decorators.py:412, in <listcomp>(.0)
#     409 class Substitution:
#     410     """
#     411     A decorator to take a function's docstring and perform string
# --> 412     substitution on it.
#     413
#     414     This decorator should be robust even if func.__doc__ is None
#     415     (for example, if -OO was passed to the interpreter)
#     416
#     417     Usage: construct a docstring.Substitution with a sequence or
#     418     dictionary suitable for performing substitution; then
#     419     decorate a suitable function with the constructed object. e.g.
#     420
#     421     sub_author_name = Substitution(author='Jason')
#     422
#     423     @sub_author_name
#     424     def some_function(x):
#     425         "%(author)s wrote this function"
#     426
#     427     # note that some_function.__doc__ is now "Jason wrote this function"
#     428
#     429     One can also use positional arguments.
#     430
#     431     sub_first_last_names = Substitution('Edgar Allen', 'Poe')
#     432
#     433     @sub_first_last_names
#     434     def some_function(x):
#     435         "%s %s wrote the Raven"
#     436     """
#     438     def __init__(self, *args, **kwargs):
#     439         if args and kwargs:
#
# KeyError: 'storage_options_versionadded'
